# %%
import pandas as pd
df = pd.read_csv('./data/training_data.csv')
for row in df.iterrows():
    print(row[1]['Word list'])
# Out:
# ['hello']
# ['hey']
# ['hi']
# ['good', 'day']
# ['Greetings']
# ['what', "'s", 'up', '?']
# ['how', 'is', 'it', 'going', '?']
# ['Hey', 'there', '!']
# ['Morning', '!']
# ['How', 'are', 'things', '?']
# ['What', "'s", 'new', '?']
# ['It', "'s", 'good', 'to', 'see', 'you']
# ["G'day", '!']
# ['Howdy', '!']
# ['What', "'s", 'up', '?']
# ['How', "'s", 'it', 'going', '?']
# ['What', "'s", 'happening', '?']
# ['What', "'s", 'the', 'story', '?']
# ['Yo', '!']
# ['Hi', 'there']
# ['Good', 'morning']
# ['Good', 'afternoon']
# ['Good', 'evening']
# ['It', "'s", 'nice', 'to', 'meet', 'you']
# ['It', "'s", 'a', 'pleasure', 'to', 'meet', 'you']
# ['Pleased', 'to', 'meet', 'you']
# ['cya']
# ['See', 'you', 'later']
# ['Goodbye']
# ['I', 'am', 'Leaving']
# ['Have', 'a', 'Good', 'day']
# ['bye']
# ['cao']
# ['see', 'ya']
# ['Have', 'a', 'good', 'day']
# ['Farewell']
# ['Have', 'a', 'nice', 'day']
# ['Have', 'a', 'good', 'evening']
# ['Have', 'a', 'good', 'night']
# ['Take', 'care']
# ...

# %%
import numpy
numpy.version.version
# Out:
# '1.23.4'
