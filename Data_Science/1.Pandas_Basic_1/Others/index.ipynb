# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Read data frame

# %% [markdown]
# ### Read the information

# %%
df = pd.read_csv('test.csv')
df
# Out:
#      Unnamed: 0         city       latd       longd  elevation_m  \
# 0             0     Adelanto  34.576111 -117.432778        875.0
# 1             1  AgouraHills  34.153333 -118.761667        281.0
# 2             2      Alameda  37.756111 -122.274444          NaN
# 3             3       Albany  37.886944 -122.297778          NaN
# 4             4     Alhambra  34.081944 -118.135000        150.0
# ..          ...          ...        ...         ...          ...
# 477         477   Yountville  38.403056 -122.362222         30.0
# 478         478        Yreka  41.726667 -122.637500        787.0
# 479         479     YubaCity  39.134722 -121.626111         18.0
# 480         480      Yucaipa  34.030278 -117.048611        798.0
# 481         481  YuccaValley  34.133333 -116.416667       1027.0
#
#      elevation_ft  population_total  area_total_sq_mi  area_land_sq_mi  \
# 0          2871.0             31765            56.027           56.009
# ...

# %% [markdown]
# ### Save as new file

# %%
df.to_csv('newfile.csv')

# %% [markdown]
# ### Information about data frame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 482 entries, 0 to 481
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          482 non-null    int64
#  1   city                482 non-null    object
#  2   latd                482 non-null    float64
#  3   longd               482 non-null    float64
#  4   elevation_m         434 non-null    float64
#  5   elevation_ft        470 non-null    float64
#  6   population_total    482 non-null    int64
#  7   area_total_sq_mi    480 non-null    float64
#  8   area_land_sq_mi     482 non-null    float64
#  9   area_water_sq_mi    481 non-null    float64
#  10  area_total_km2      477 non-null    float64
#  11  area_land_km2       478 non-null    float64
#  12  area_water_km2      478 non-null    float64
#  13  area_water_percent  477 non-null    float64
# dtypes: float64(11), int64(2), object(1)
# memory usage: 52.8+ KB

# %% [markdown]
# ### Get information a column or multiple column

# %%
df['city']
# Out:
# 0         Adelanto
# 1      AgouraHills
# 2          Alameda
# 3           Albany
# 4         Alhambra
#           ...
# 477     Yountville
# 478          Yreka
# 479       YubaCity
# 480        Yucaipa
# 481    YuccaValley
# Name: city, Length: 482, dtype: object

# %%
df[['city', 'population_total']]
# Out:
#             city  population_total
# 0       Adelanto             31765
# 1    AgouraHills             20330
# 2        Alameda             75467
# 3         Albany             18969
# 4       Alhambra             83089
# ..           ...               ...
# 477   Yountville              2933
# 478        Yreka              7765
# 479     YubaCity             64925
# 480      Yucaipa             51367
# 481  YuccaValley             20700
#
# [482 rows x 2 columns]

# %% [markdown]
# ### Get information of a row or multiple rows

# %%
df.head(5) # get 5 first rows
# Out:
#    Unnamed: 0         city       latd       longd  elevation_m  elevation_ft  \
# 0           0     Adelanto  34.576111 -117.432778        875.0        2871.0
# 1           1  AgouraHills  34.153333 -118.761667        281.0         922.0
# 2           2      Alameda  37.756111 -122.274444          NaN          33.0
# 3           3       Albany  37.886944 -122.297778          NaN          43.0
# 4           4     Alhambra  34.081944 -118.135000        150.0         492.0
#
#    population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# 0             31765            56.027           56.009             0.018
# 1             20330             7.822            7.793             0.029
# 2             75467            22.960           10.611            12.349
# 3             18969             5.465            1.788             3.677
# 4             83089             7.632            7.631             0.001
#
# ...

# %%
df.tail(5) # get 5 last rows
# Out:
#      Unnamed: 0         city       latd       longd  elevation_m  \
# 477         477   Yountville  38.403056 -122.362222         30.0
# 478         478        Yreka  41.726667 -122.637500        787.0
# 479         479     YubaCity  39.134722 -121.626111         18.0
# 480         480      Yucaipa  34.030278 -117.048611        798.0
# 481         481  YuccaValley  34.133333 -116.416667       1027.0
#
#      elevation_ft  population_total  area_total_sq_mi  area_land_sq_mi  \
# 477          98.0              2933             1.531            1.531
# 478        2582.0              7765            10.053            9.980
# 479          59.0             64925            14.656           14.578
# 480        2618.0             51367            27.893           27.888
# 481        3369.0             20700            40.015           40.015
#
#      area_water_sq_mi  area_total_km2  area_land_km2  area_water_km2  \
# 477             0.000           3.966          3.966           0.000
# ...

# %%
df[5:10] # get rows from 5 - 10
# Out:
#    Unnamed: 0            city       latd       longd  elevation_m  \
# 5           5      AlisoViejo  33.575000 -117.725556        127.0
# 6           6         Alturas  41.487222 -120.542500       1332.0
# 7           7      AmadorCity  38.419444 -120.824167        280.0
# 8           8  AmericanCanyon  38.168056 -122.252500         14.0
# 9           9         Anaheim  33.836111 -117.889722         48.0
#
#    elevation_ft  population_total  area_total_sq_mi  area_land_sq_mi  \
# 5         417.0             47823             7.472            7.472
# 6        4370.0              2827             2.449            2.435
# 7         919.0               185             0.314            0.314
# 8          46.0             19454             4.845            4.837
# 9         157.0            336000            50.811           49.835
#
#    area_water_sq_mi  area_total_km2  area_land_km2  area_water_km2  \
# 5             0.000          19.352         19.352           0.000
# ...

# %% [markdown]
# ### Get information of a row or multiple rows with condition

# %%
# Basic
df[df["population_total"] < 500]
# Out:
#      Unnamed: 0        city       latd       longd  elevation_m  elevation_ft  \
# 7             7  AmadorCity  38.419444 -120.824167        280.0         919.0
# 190         190    Industry  34.016667 -117.950000         98.0         322.0
# 326         326  PointArena  38.908889 -123.693056         36.0         118.0
# 327         327      Pomona  34.060833 -117.755833        259.0         850.0
# 366         366    SandCity  36.617222 -121.848333         22.0          72.0
# 428         428      Tehama  40.024444 -122.123889         64.0         210.0
# 435         435    Trinidad  41.059167 -124.143056         53.0         174.0
# 448         448      Vernon  34.001111 -118.211111         62.0         203.0
#
#      population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# 7                 185             0.314            0.314             0.000
# 190               219            12.064           11.785             0.279
# ...

# %%
# using loc
df.loc[(df['population_total'] > 19000) & (df['population_total'] < 20000)]
# Out:
#      Unnamed: 0            city       latd       longd  elevation_m  \
# 8             8  AmericanCanyon  38.168056 -122.252500         14.0
# 18           18           Arvin  35.209167 -118.828333        137.0
# 175         175    HermosaBeach  33.866389 -118.399722          8.0
#
#      elevation_ft  population_total  area_total_sq_mi  area_land_sq_mi  \
# 8            46.0             19454             4.845            4.837
# 18          449.0             19304             4.819            4.819
# 175          26.0             19506             1.427            1.427
#
#      area_water_sq_mi  area_total_km2  area_land_km2  area_water_km2  \
# 8               0.008          12.548         12.527           0.021
# 18              0.000          12.482         12.482           0.000
# 175             0.000           3.695          3.695           0.000
#
#      area_water_percent
# 8                  0.17
# 18                 0.00
# 175                0.00

# %%
# Select row with condition and set column is displayed
df.loc[(df['population_total'] > 19000) & (df['population_total'] < 20000), ['city', 'latd']]
# Out:
#                city       latd
# 8    AmericanCanyon  38.168056
# 18            Arvin  35.209167
# 175    HermosaBeach  33.866389

# %% [markdown]
# # Edit data frame

# %% [markdown]
# ### Add new column

# %%
# add new column test_add
df['test_add'] = df['population_total']*2
df
# Out:
#      Unnamed: 0         city       latd       longd  elevation_m  \
# 0             0     Adelanto  34.576111 -117.432778        875.0
# 1             1  AgouraHills  34.153333 -118.761667        281.0
# 2             2      Alameda  37.756111 -122.274444          NaN
# 3             3       Albany  37.886944 -122.297778          NaN
# 4             4     Alhambra  34.081944 -118.135000        150.0
# ..          ...          ...        ...         ...          ...
# 477         477   Yountville  38.403056 -122.362222         30.0
# 478         478        Yreka  41.726667 -122.637500        787.0
# 479         479     YubaCity  39.134722 -121.626111         18.0
# 480         480      Yucaipa  34.030278 -117.048611        798.0
# 481         481  YuccaValley  34.133333 -116.416667       1027.0
#
#      elevation_ft  population_total  area_total_sq_mi  area_land_sq_mi  \
# 0          2871.0             31765            56.027           56.009
# ...

# %%
# check = 1 if column population_total > 20000 else check =0
df['check'] = np.where(df['population_total'] > 20000, 1,0)
df
# Out:
#      Unnamed: 0         city       latd       longd  elevation_m  \
# 0             0     Adelanto  34.576111 -117.432778        875.0
# 1             1  AgouraHills  34.153333 -118.761667        281.0
# 2             2      Alameda  37.756111 -122.274444          NaN
# 3             3       Albany  37.886944 -122.297778          NaN
# 4             4     Alhambra  34.081944 -118.135000        150.0
# ..          ...          ...        ...         ...          ...
# 477         477   Yountville  38.403056 -122.362222         30.0
# 478         478        Yreka  41.726667 -122.637500        787.0
# 479         479     YubaCity  39.134722 -121.626111         18.0
# 480         480      Yucaipa  34.030278 -117.048611        798.0
# 481         481  YuccaValley  34.133333 -116.416667       1027.0
#
#      elevation_ft  population_total  area_total_sq_mi  area_land_sq_mi  \
# 0          2871.0             31765            56.027           56.009
# ...

# %% [markdown]
# ### Delete column

# %%
df = df.drop(columns=['test_add'])
# or df.drop(columns=['test_add'], inplace=True)
df
# Out:
#      Unnamed: 0         city       latd       longd  elevation_m  \
# 0             0     Adelanto  34.576111 -117.432778        875.0
# 1             1  AgouraHills  34.153333 -118.761667        281.0
# 2             2      Alameda  37.756111 -122.274444          NaN
# 3             3       Albany  37.886944 -122.297778          NaN
# 4             4     Alhambra  34.081944 -118.135000        150.0
# ..          ...          ...        ...         ...          ...
# 477         477   Yountville  38.403056 -122.362222         30.0
# 478         478        Yreka  41.726667 -122.637500        787.0
# 479         479     YubaCity  39.134722 -121.626111         18.0
# 480         480      Yucaipa  34.030278 -117.048611        798.0
# 481         481  YuccaValley  34.133333 -116.416667       1027.0
#
#      elevation_ft  population_total  area_total_sq_mi  area_land_sq_mi  \
# 0          2871.0             31765            56.027           56.009
# ...

# %% [markdown]
# ### Delete row

# %%
df = df.drop(index=[1,2,3])
df
# Out:
#      Unnamed: 0         city       latd       longd  elevation_m  \
# 0             0     Adelanto  34.576111 -117.432778        875.0
# 4             4     Alhambra  34.081944 -118.135000        150.0
# 5             5   AlisoViejo  33.575000 -117.725556        127.0
# 6             6      Alturas  41.487222 -120.542500       1332.0
# 7             7   AmadorCity  38.419444 -120.824167        280.0
# ..          ...          ...        ...         ...          ...
# 477         477   Yountville  38.403056 -122.362222         30.0
# 478         478        Yreka  41.726667 -122.637500        787.0
# 479         479     YubaCity  39.134722 -121.626111         18.0
# 480         480      Yucaipa  34.030278 -117.048611        798.0
# 481         481  YuccaValley  34.133333 -116.416667       1027.0
#
#      elevation_ft  population_total  area_total_sq_mi  area_land_sq_mi  \
# 0          2871.0             31765            56.027           56.009
# ...

# %% [markdown]
# # Statistic

# %% [markdown]
# ### Sort

# %%
# Ascending
df.sort_values(by = ['population_total'])
# Out:
#      Unnamed: 0          city       latd       longd  elevation_m  \
# 327         327        Pomona  34.060833 -117.755833        259.0
# 448         448        Vernon  34.001111 -118.211111         62.0
# 7             7    AmadorCity  38.419444 -120.824167        280.0
# 190         190      Industry  34.016667 -117.950000         98.0
# 366         366      SandCity  36.617222 -121.848333         22.0
# ..          ...           ...        ...         ...          ...
# 150         150        Fresno  36.750000 -119.766667          NaN
# 370         370  SanFrancisco  37.783333 -122.416667          NaN
# 375         375       SanJose  37.333333 -121.900000         26.0
# 367         367      SanDiego  32.715000 -117.162500          6.0
# 239         239    LosAngeles  34.050000 -118.250000         71.0
#
#      elevation_ft  population_total  area_total_sq_mi  area_land_sq_mi  \
# 327         850.0                 1            22.964           22.952
# ...

# %%
# Decrease
df.sort_values(by = ['population_total'], ascending=False)
# Out:
#      Unnamed: 0          city       latd       longd  elevation_m  \
# 239         239    LosAngeles  34.050000 -118.250000         71.0
# 367         367      SanDiego  32.715000 -117.162500          6.0
# 375         375       SanJose  37.333333 -121.900000         26.0
# 370         370  SanFrancisco  37.783333 -122.416667          NaN
# 150         150        Fresno  36.750000 -119.766667          NaN
# ..          ...           ...        ...         ...          ...
# 366         366      SandCity  36.617222 -121.848333         22.0
# 190         190      Industry  34.016667 -117.950000         98.0
# 7             7    AmadorCity  38.419444 -120.824167        280.0
# 448         448        Vernon  34.001111 -118.211111         62.0
# 327         327        Pomona  34.060833 -117.755833        259.0
#
#      elevation_ft  population_total  area_total_sq_mi  area_land_sq_mi  \
# 239           2.0           3884307           503.000          469.000
# ...

# %% [markdown]
# ### Describe

# %%
df.describe()
# Out:
#        Unnamed: 0        latd       longd  elevation_m  elevation_ft  \
# count  479.000000  479.000000  479.000000   433.000000    467.000000
# mean   241.993737   36.091933 -119.829737   180.184411    568.675161
# std    138.430556    2.300780    2.147998   309.851997   1003.749349
# min      0.000000   32.578333 -124.263333   -34.000000   -180.000000
# 25%    122.500000   33.971667 -121.945278    22.000000     69.000000
# 50%    242.000000   36.202778 -119.703056    67.000000    200.000000
# 75%    361.500000   37.895972 -117.973056   172.000000    515.000000
# max    481.000000   41.965000 -114.596389  2402.000000   7880.000000
#
#        population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# count      4.790000e+02        477.000000       479.000000        478.000000
# mean       6.506178e+04         18.482182        16.904303          1.566019
# std        2.038191e+05         36.468932        32.785946          9.506650
# ...

# %% [markdown]
# # Draw chart

# %%
new_df = df.head(20)

# %% [markdown]
# ### line chart

# %%
new_df['population_total'].plot.line()
# Out:
# <AxesSubplot: >

# %%
new_df['population_total'].plot.line(color='red', linestyle = '-.')
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### bar chart

# %%
new_df['population_total'].plot.bar()
# Out:
# <AxesSubplot: >

# %%
new_df['population_total'].plot.bar(color='purple')
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### pie chart

# %%
new_df['population_total'].plot.pie()
# Out:
# <AxesSubplot: ylabel='population_total'>

# %%
# Get two column
group_df = new_df[['city','population_total']]

# %%
# group by city
group_df = group_df.groupby('city').size()

# %%
group_df
# Out:
# city
# Adelanto          1
# Alhambra          1
# AlisoViejo        1
# Alturas           1
# AmadorCity        1
# AmericanCanyon    1
# Anaheim           1
# Anderson          1
# AngelsCamp        1
# Antioch           1
# AppleValley       1
# Arcadia           1
# Arcata            1
# ArroyoGrande      1
# Artesia           1
# Arvin             1
# Atascadero        1
# Atherton          1
# Atwater           1
# Auburn            1
# dtype: int64

# %%
group_df.plot.pie()
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Clear data

# %%
# Check null
new_df.isna()
# Out:
#     Unnamed: 0   city   latd  longd  elevation_m  elevation_ft  \
# 0        False  False  False  False        False         False
# 4        False  False  False  False        False         False
# 5        False  False  False  False        False         False
# 6        False  False  False  False        False         False
# 7        False  False  False  False        False         False
# 8        False  False  False  False        False         False
# 9        False  False  False  False        False         False
# 10       False  False  False  False        False         False
# 11       False  False  False  False        False         False
# 12       False  False  False  False        False         False
# 13       False  False  False  False        False         False
# 14       False  False  False  False        False         False
# 15       False  False  False  False         True         False
# 16       False  False  False  False        False         False
# ...

# %%
# Fill all data NULL is 1
new_df.fillna(1)
# Out:
#     Unnamed: 0            city       latd       longd  elevation_m  \
# 0            0        Adelanto  34.576111 -117.432778        875.0
# 4            4        Alhambra  34.081944 -118.135000        150.0
# 5            5      AlisoViejo  33.575000 -117.725556        127.0
# 6            6         Alturas  41.487222 -120.542500       1332.0
# 7            7      AmadorCity  38.419444 -120.824167        280.0
# 8            8  AmericanCanyon  38.168056 -122.252500         14.0
# 9            9         Anaheim  33.836111 -117.889722         48.0
# 10          10        Anderson  40.452222 -122.296667        132.0
# 11          11      AngelsCamp  38.068333 -120.539722        420.0
# 12          12         Antioch  38.005000 -121.805833         13.0
# 13          13     AppleValley  34.516667 -117.216667        898.0
# 14          14         Arcadia  34.132778 -118.036389        147.0
# 15          15          Arcata  40.866389 -124.082778          1.0
# ...
